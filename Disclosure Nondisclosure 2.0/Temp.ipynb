# %%
import spacy
from spacy import displacy
from os import listdir

nlp = spacy.load('en')

# %%
PERSONS = ['I', 'ME', 'MY', 'MINE', 'YOU', 'YOUR', 'YOURS', 'HE', 'SHE', 'HIS', 'HER', 'HIM', 'THEY', 'THEM', 'THEMSELVES', 'OUR', 'WE']
LOCATIONS = ['LOC', 'GPE', 'ORG', 'FAC']
ALL_ENTITIES = LOCATIONS + ['PERSON', 'HEALTH', 'MONEY', 'DATE', 'TIME']

# %% [markdown]
# **Non Disclosure Experiment Data**

# %%
# for filename in sorted(listdir('data/non_disclosure')):
#     if not filename.endswith('.txt'):
#         continue
        
#     with open('data/non_disclosure/' + filename) as f:
#         content = f.read()
#         doc = nlp(u''+content)
#         # print(content)
#         displacy.render(doc, style='ent', jupyter=True) 
#         # print('-'*50)

# %% [markdown]
# **Disclosure Experiment Data**

# %%
# for filename in sorted(listdir('data/disclosure')):
#     if not filename.endswith('.txt'):
#         continue
        
#     with open('data/disclosure/' + filename) as f:
#         content = f.read()
#         doc = nlp(u''+content)
#         # print(content)
#         displacy.render(doc, style='ent', jupyter=True) 
#         # print('-'*50)

# %% [markdown]
# ### Manual Labeling of Data

# %%
from os import listdir
from string import punctuation
import nltk.data

# %%
def write_docs(dnd, data):
    with open(dnd + '.tsv', 'a') as f:
        f.write(data)
        print('Writing file done!')

# %%
def process_docs(path):
    with open(path, 'r') as f:
        non_disclosure = []
        disclosure = []

        text = f.read()
        
        sent_detector = nltk.data.load('tokenizers/punkt/english.pickle')
        lines = sent_detector.tokenize(text.strip())
        
        for line in lines:
            # remove punctuation from each token. Except ', char
            tokens = line.split()
            print(tokens)
            table = str.maketrans('', '', '!"#$%&()*+-./:;<=>?@[\]^_`{|}~')
            tokens = [w.translate(table) for w in tokens]
            doc = ' '.join(tokens)

            doc = nlp(u''+doc)
            new_doc = ''

            entity = 0
            spacy_tokens = []
            
            for t in doc:
                spacy_tokens.append(t.text)
                
                if t.ent_type_ == '':
                    if t.text.upper() in PERSONS:
                        entity = entity+1
                        
                        index = spacy_tokens.index(t.text)
                        ## Replace with Entity Label
                        # spacy_tokens[index] = 'PERSON'
                    else:
                        pass
                elif t.ent_type_ in ALL_ENTITIES:
                    entity = entity+1
                    
                    index = spacy_tokens.index(t.text)
                    ## Replace with Entity Label
                    # spacy_tokens[index] = t.ent_type_.upper()                    
            
            new_doc = ' '.join(spacy_tokens)
            
            if entity > 1:
                if len(set([t.upper() for t in spacy_tokens]).intersection(set(PERSONS))) > 0:
                    # print('DISCLOSURE: ', new_doc)
                    # disclosure.append(new_doc)
                    write_docs('Manually_Labeled_Data/disclosure', '1\t' + new_doc + '\n')
                    continue
                else:
                    # print('NON-DISCLOSURE: ', new_doc)
                    # non_disclosure.append(new_doc)
                    write_docs('Manually_Labeled_Data/non-disclosure', '0\t' + new_doc + '\n')
                    continue            
            else:
                # print('NON-DISCLOSURE: ', new_doc)
                # non_disclosure.append(new_doc)
                write_docs('Manually_Labeled_Data/non-disclosure', '0\t' + new_doc + '\n')
                continue     
    
    print('\n')

# %%
directory = 'data/aws_food_reviews'

# Make sure have new blank files
with open('Manually_Labeled_Data/non-disclosure.tsv', 'w') as f:
    f.write('')
with open('Manually_Labeled_Data/disclosure.tsv', 'w') as f:
    f.write('')  

i = 0
for filename in sorted(listdir(directory)):
    if not filename.endswith(".txt"):
        continue
        
#     if i >= 2:
#         break      
        
    print(filename)
    path = directory + '/' + filename    
    process_docs(path)
    i = i+1
# Out:
# 00000_aws_food_reviews.txt
# ['I', 'have', 'to', 'admit,', 'I', 'was', 'a', 'sucker', 'for', 'the', 'large', 'quantity,', '12', 'oz,', 'when', 'shopping', 'for', 'hot', 'sauces', '...but', 'now', 'seeing', 'the', 'size', 'of', 'the', 'bottle,', 'it', 'reminds', 'of', 'wing-sauce', 'bottle', 'sizes.']
# Writing file done!
# ['Plastic', 'bottle.']
# Writing file done!
# ['It', 'does', 'have', 'a', 'convenient', 'squirt', 'top.']
# Writing file done!
# ['But', 'overall,', 'not', 'very', 'hot', 'or', 'tasty,', 'and', 'made', 'mostly', 'from', 'jalape&ntilde;os.']
# Writing file done!
# ['If', 'I', 'had', 'seen', 'the', 'ingredients', 'list', 'I', 'would', 'not', 'have', 'bought', 'it:<br', '/>Jalapenos<br', '/>Water<br', '/>Vinegar<br', '/>Brown', 'Sugar<br', '/>Lime', 'Juice<br', '/>Fish', 'Sauce<br', '/>Cilantro<br', '/>Habanero<br', '/>Garlic<br', '/>Spice', 'Blend<br', '/>Salt<br', '/>Potassium', 'Sorbate<br', '/>Xanthan', 'Gum']
# Writing file done!
#
#
# 00001_aws_food_reviews.txt
# ['I', 'have', 'bought', 'several', 'of', 'the', 'Vitality', 'canned', 'dog', 'food', 'products', 'and', 'have', 'found', 'them', 'all', 'to', 'be', 'of', 'good', 'quality.']
# Writing file done!
# ['The', 'product', 'looks', 'more', 'like', 'a', 'stew', 'than', 'a', 'processed', 'meat', 'and', 'it', 'smells', 'better.']
# Writing file done!
# ['My', 'Labrador', 'is', 'finicky', 'and', 'she', 'appreciates', 'this', 'product', 'better', 'than', 'most.']
# Writing file done!
#
#
# 00002_aws_food_reviews.txt
# ['Product', 'arrived', 'labeled', 'as', 'Jumbo', 'Salted', 'Peanuts...the', 'peanuts', 'were', 'actually', 'small', 'sized', 'unsalted.']
# Writing file done!
# ['Not', 'sure', 'if', 'this', 'was', 'an', 'error', 'or', 'if', 'the', 'vendor', 'intended', 'to', 'represent', 'the', 'product', 'as', '"Jumbo".']
# Writing file done!
#
#
# 00003_aws_food_reviews.txt
# ['This', 'is', 'a', 'confection', 'that', 'has', 'been', 'around', 'a', 'few', 'centuries.']
# Writing file done!
# ['It', 'is', 'a', 'light,', 'pillowy', 'citrus', 'gelatin', 'with', 'nuts', '-', 'in', 'this', 'case', 'Filberts.']
# Writing file done!
# ['And', 'it', 'is', 'cut', 'into', 'tiny', 'squares', 'and', 'then', 'liberally', 'coated', 'with', 'powdered', 'sugar.']
# Writing file done!
# ['And', 'it', 'is', 'a', 'tiny', 'mouthful', 'of', 'heaven.']
# Writing file done!
# ['Not', 'too', 'chewy,', 'and', 'very', 'flavorful.']
# Writing file done!
# ['I', 'highly', 'recommend', 'this', 'yummy', 'treat.']
# Writing file done!
# ['If', 'you', 'are', 'familiar', 'with', 'the', 'story', 'of', 'C.S.']
# Writing file done!
# ["Lewis'", '"The', 'Lion,', 'The', 'Witch,', 'and', 'The', 'Wardrobe"', '-', 'this', 'is', 'the', 'treat', 'that', 'seduces', 'Edmund', 'into', 'selling', 'out', 'his', 'Brother', 'and', 'Sisters', 'to', 'the', 'Witch.']
# Writing file done!
#
#
# 00004_aws_food_reviews.txt
# ['If', 'you', 'are', 'looking', 'for', 'the', 'secret', 'ingredient', 'in', 'Robitussin', 'I', 'believe', 'I', 'have', 'found', 'it.']
# Writing file done!
# ['I', 'got', 'this', 'in', 'addition', 'to', 'the', 'Root', 'Beer', 'Extract', 'I', 'ordered', '(which', 'was', 'good)', 'and', 'made', 'some', 'cherry', 'soda.']
# Writing file done!
# ['The', 'flavor', 'is', 'very', 'medicinal.']
# Writing file done!
#
#
# 00005_aws_food_reviews.txt
# ['Great', 'taffy', 'at', 'a', 'great', 'price.']
# Writing file done!
# ['There', 'was', 'a', 'wide', 'assortment', 'of', 'yummy', 'taffy.']
# Writing file done!
# ['Delivery', 'was', 'very', 'quick.']
# Writing file done!
# ['If', 'your', 'a', 'taffy', 'lover,', 'this', 'is', 'a', 'deal.']
# Writing file done!
#
#
# 00006_aws_food_reviews.txt
# ['I', 'got', 'a', 'wild', 'hair', 'for', 'taffy', 'and', 'ordered', 'this', 'five', 'pound', 'bag.']
# Writing file done!
# ['The', 'taffy', 'was', 'all', 'very', 'enjoyable', 'with', 'many', 'flavors:', 'watermelon,', 'root', 'beer,', 'melon,', 'peppermint,', 'grape,', 'etc.']
# Writing file done!
# ['My', 'only', 'complaint', 'is', 'there', 'was', 'a', 'bit', 'too', 'much', 'red/black', 'licorice-flavored', 'pieces', '(just', 'not', 'my', 'particular', 'favorites).']
# Writing file done!
# ['Between', 'me,', 'my', 'kids,', 'and', 'my', 'husband,', 'this', 'lasted', 'only', 'two', 'weeks!']
# Writing file done!
# ['I', 'would', 'recommend', 'this', 'brand', 'of', 'taffy', '--', 'it', 'was', 'a', 'delightful', 'treat.']
# Writing file done!
#
#
# 00007_aws_food_reviews.txt
# ['This', 'saltwater', 'taffy', 'had', 'great', 'flavors', 'and', 'was', 'very', 'soft', 'and', 'chewy.']
# Writing file done!
# ['Each', 'candy', 'was', 'individually', 'wrapped', 'well.']
# Writing file done!
# ['None', 'of', 'the', 'candies', 'were', 'stuck', 'together,', 'which', 'did', 'happen', 'in', 'the', 'expensive', 'version,', "Fralinger's."]
# Writing file done!
# ['Would', 'highly', 'recommend', 'this', 'candy!']
# Writing file done!
# ['I', 'served', 'it', 'at', 'a', 'beach-themed', 'party', 'and', 'everyone', 'loved', 'it!']
# Writing file done!
#
#
# 00008_aws_food_reviews.txt
# ['This', 'taffy', 'is', 'so', 'good.']
# Writing file done!
# ['It', 'is', 'very', 'soft', 'and', 'chewy.']
# Writing file done!
# ['The', 'flavors', 'are', 'amazing.']
# Writing file done!
# ['I', 'would', 'definitely', 'recommend', 'you', 'buying', 'it.']
# Writing file done!
# ['Very', 'satisfying!']
# Writing file done!
# ['!']
# Writing file done!
#
#
# 00009_aws_food_reviews.txt
# ['Right', 'now', "I'm", 'mostly', 'just', 'sprouting', 'this', 'so', 'my', 'cats', 'can', 'eat', 'the', 'grass.']
# Writing file done!
# ['They', 'love', 'it.']
# Writing file done!
# ['I', 'rotate', 'it', 'around', 'with', 'Wheatgrass', 'and', 'Rye', 'too']
# Writing file done!
#
#
# 00010_aws_food_reviews.txt
# ['This', 'is', 'a', 'very', 'healthy', 'dog', 'food.']
# Writing file done!
# ['Good', 'for', 'their', 'digestion.']
# Writing file done!
# ['Also', 'good', 'for', 'small', 'puppies.']
# Writing file done!
# ['My', 'dog', 'eats', 'her', 'required', 'amount', 'at', 'every', 'feeding.']
# Writing file done!
#
#
# 00011_aws_food_reviews.txt
# ['I', "don't", 'know', 'if', "it's", 'the', 'cactus', 'or', 'the', 'tequila', 'or', 'just', 'the', 'unique', 'combination', 'of', 'ingredients,', 'but', 'the', 'flavour', 'of', 'this', 'hot', 'sauce', 'makes', 'it', 'one', 'of', 'a', 'kind!']
# Writing file done!
# ['We', 'picked', 'up', 'a', 'bottle', 'once', 'on', 'a', 'trip', 'we', 'were', 'on', 'and', 'brought', 'it', 'back', 'home', 'with', 'us', 'and', 'were', 'totally', 'blown', 'away!']
# Writing file done!
# ['When', 'we', 'realized', 'that', 'we', 'simply', "couldn't", 'find', 'it', 'anywhere', 'in', 'our', 'city', 'we', 'were', 'bummed.<br', '/><br', '/>Now,', 'because', 'of', 'the', 'magic', 'of', 'the', 'internet,', 'we', 'have', 'a', 'case', 'of', 'the', 'sauce', 'and', 'are', 'ecstatic', 'because', 'of', 'it.<br', '/><br', '/>If', 'you', 'love', 'hot', 'sauce..I', 'mean', 'really', 'love', 'hot', 'sauce,', 'but', "don't", 'want', 'a', 'sauce', 'that', 'tastelessly', 'burns', 'your', 'throat,', 'grab', 'a', 'bottle', 'of', 'Tequila', 'Picante', 'Gourmet', 'de', 'Inclan.']
# Writing file done!
# ['Just', 'realize', 'that', 'once', 'you', 'taste', 'it,', 'you', 'will', 'never', 'want', 'to', 'use', 'any', 'other', 'sauce.<br', '/><br', '/>Thank', 'you', 'for', 'the', 'personal,', 'incredible', 'service!']
# Writing file done!
#
#
# 00012_aws_food_reviews.txt
# ['One', 'of', 'my', 'boys', 'needed', 'to', 'lose', 'some', 'weight', 'and', 'the', 'other', "didn't."]
# Writing file done!
# ['I', 'put', 'this', 'food', 'on', 'the', 'floor', 'for', 'the', 'chubby', 'guy,', 'and', 'the', 'protein-rich,', 'no', 'by-product', 'food', 'up', 'higher', 'where', 'only', 'my', 'skinny', 'boy', 'can', 'jump.']
# Writing file done!
# ['The', 'higher', 'food', 'sits', 'going', 'stale.']
# Writing file done!
# ['They', 'both', 'really', 'go', 'for', 'this', 'food.']
# Writing file done!
# ['And', 'my', 'chubby', 'boy', 'has', 'been', 'losing', 'about', 'an', 'ounce', 'a', 'week.']
# Writing file done!
#
#
# 00013_aws_food_reviews.txt
# ['My', 'cats', 'have', 'been', 'happily', 'eating', 'Felidae', 'Platinum', 'for', 'more', 'than', 'two', 'years.']
# Writing file done!
# ['I', 'just', 'got', 'a', 'new', 'bag', 'and', 'the', 'shape', 'of', 'the', 'food', 'is', 'different.']
# Writing file done!
# ['They', 'tried', 'the', 'new', 'food', 'when', 'I', 'first', 'put', 'it', 'in', 'their', 'bowls', 'and', 'now', 'the', 'bowls', 'sit', 'full', 'and', 'the', 'kitties', 'will', 'not', 'touch', 'the', 'food.']
# Writing file done!
# ["I've", 'noticed', 'similar', 'reviews', 'related', 'to', 'formula', 'changes', 'in', 'the', 'past.']
# Writing file done!
# ['Unfortunately,', 'I', 'now', 'need', 'to', 'find', 'a', 'new', 'food', 'that', 'my', 'cats', 'will', 'eat.']
# Writing file done!
#
#
# 00014_aws_food_reviews.txt
# ['good', 'flavor!']
# Writing file done!
# ['these', 'came', 'securely', 'packed...', 'they', 'were', 'fresh', 'and', 'delicious!']
# Writing file done!
# ['i', 'love', 'these', 'Twizzlers!']
# Writing file done!
#
#
# 00015_aws_food_reviews.txt
# ['The', 'Strawberry', 'Twizzlers', 'are', 'my', 'guilty', 'pleasure', '-', 'yummy.']
# Writing file done!
# ['Six', 'pounds', 'will', 'be', 'around', 'for', 'a', 'while', 'with', 'my', 'son', 'and', 'I.']
# Writing file done!
#
#
# 00016_aws_food_reviews.txt
# ['My', 'daughter', 'loves', 'twizzlers', 'and', 'this', 'shipment', 'of', 'six', 'pounds', 'really', 'hit', 'the', 'spot.']
# Writing file done!
# ["It's", 'exactly', 'what', 'you', 'would', 'expect...six', 'packages', 'of', 'strawberry', 'twizzlers.']
# Writing file done!
#
#
# 00017_aws_food_reviews.txt
# ['I', 'love', 'eating', 'them', 'and', 'they', 'are', 'good', 'for', 'watching', 'TV', 'and', 'looking', 'at', 'movies!']
# Writing file done!
# ['It', 'is', 'not', 'too', 'sweet.']
# Writing file done!
# ['I', 'like', 'to', 'transfer', 'them', 'to', 'a', 'zip', 'lock', 'baggie', 'so', 'they', 'stay', 'fresh', 'so', 'I', 'can', 'take', 'my', 'time', 'eating', 'them.']
# Writing file done!
#
#
# 00018_aws_food_reviews.txt
# ['I', 'am', 'very', 'satisfied', 'with', 'my', 'Twizzler', 'purchase.']
# Writing file done!
# ['I', 'shared', 'these', 'with', 'others', 'and', 'we', 'have', 'all', 'enjoyed', 'them.']
# Writing file done!
# ['I', 'will', 'definitely', 'be', 'ordering', 'more.']
# Writing file done!
#
#
# 00019_aws_food_reviews.txt
# ['Twizzlers,', 'Strawberry', 'my', 'childhood', 'favorite', 'candy,', 'made', 'in', 'Lancaster', 'Pennsylvania', 'by', 'Y', '&', 'S', 'Candies,', 'Inc.', 'one', 'of', 'the', 'oldest', 'confectionery', 'Firms', 'in', 'the', 'United', 'States,', 'now', 'a', 'Subsidiary', 'of', 'the', 'Hershey', 'Company,', 'the', 'Company', 'was', 'established', 'in', '1845', 'as', 'Young', 'and', 'Smylie,', 'they', 'also', 'make', 'Apple', 'Licorice', 'Twists,', 'Green', 'Color', 'and', 'Blue', 'Raspberry', 'Licorice', 'Twists,', 'I', 'like', 'them', 'all<br', '/><br', '/>I', 'keep', 'it', 'in', 'a', 'dry', 'cool', 'place', 'because', 'is', 'not', 'recommended', 'it', 'to', 'put', 'it', 'in', 'the', 'fridge.']
# Writing file done!
# ['According', 'to', 'the', 'Guinness', 'Book', 'of', 'Records,', 'the', 'longest', 'Licorice', 'Twist', 'ever', 'made', 'measured', '1.200', 'Feet', '(370', 'M)', 'and', 'weighted', '100', 'Pounds', '(45', 'Kg)', 'and', 'was', 'made', 'by', 'Y', '&', 'S', 'Candies,', 'Inc.']
# Writing file done!
# ['This', 'Record-Breaking', 'Twist', 'became', 'a', 'Guinness', 'World', 'Record', 'on', 'July', '19,', '1998.']
# Writing file done!
# ['This', 'Product', 'is', 'Kosher!']
# Writing file done!
# ['Thank', 'You']
# Writing file done!
#
#
# 00020_aws_food_reviews.txt
# ['Candy', 'was', 'delivered', 'very', 'fast', 'and', 'was', 'purchased', 'at', 'a', 'reasonable', 'price.']
# Writing file done!
# ['I', 'was', 'home', 'bound', 'and', 'unable', 'to', 'get', 'to', 'a', 'store', 'so', 'this', 'was', 'perfect', 'for', 'me.']
# Writing file done!
#
#
# 00021_aws_food_reviews.txt
# ['My', 'husband', 'is', 'a', 'Twizzlers', 'addict.']
# Writing file done!
# ["We've", 'bought', 'these', 'many', 'times', 'from', 'Amazon', 'because', "we're", 'government', 'employees', 'living', 'overseas', 'and', "can't", 'get', 'them', 'in', 'the', 'country', 'we', 'are', 'assigned', 'to.']
# Writing file done!
# ["They've", 'always', 'been', 'fresh', 'and', 'tasty,', 'packed', 'well', 'and', 'arrive', 'in', 'a', 'timely', 'manner.']
# Writing file done!
#
#
# 00022_aws_food_reviews.txt
# ['I', 'bought', 'these', 'for', 'my', 'husband', 'who', 'is', 'currently', 'overseas.']
# Writing file done!
# ['He', 'loves', 'these,', 'and', 'apparently', 'his', 'staff', 'likes', 'them', 'also.<br', '/>There', 'are', 'generous', 'amounts', 'of', 'Twizzlers', 'in', 'each', '16-ounce', 'bag,', 'and', 'this', 'was', 'well', 'worth', 'the', 'price.']
# Writing file done!
# ['<a', 'href="http://www.amazon.com/gp/product/B001GVISJM">Twizzlers,', 'Strawberry,', '16-Ounce', 'Bags', '(Pack', 'of', '6)</a>']
# Writing file done!
#
#
# 00023_aws_food_reviews.txt
# ['I', 'can', 'remember', 'buying', 'this', 'candy', 'as', 'a', 'kid', 'and', 'the', 'quality', "hasn't", 'dropped', 'in', 'all', 'these', 'years.']
# Writing file done!
# ['Still', 'a', 'superb', 'product', 'you', "won't", 'be', 'disappointed', 'with.']
# Writing file done!
#
#
# 00024_aws_food_reviews.txt
# ['I', 'love', 'this', 'candy.']
# Writing file done!
# ['After', 'weight', 'watchers', 'I', 'had', 'to', 'cut', 'back', 'but', 'still', 'have', 'a', 'craving', 'for', 'it.']
# Writing file done!
#
#
# 00025_aws_food_reviews.txt
# ['I', 'have', 'lived', 'out', 'of', 'the', 'US', 'for', 'over', '7', 'yrs', 'now,', 'and', 'I', 'so', 'miss', 'my', 'Twizzlers!!']
# Writing file done!
# ['When', 'I', 'go', 'back', 'to', 'visit', 'or', 'someone', 'visits', 'me,', 'I', 'always', 'stock', 'up.']
# Writing file done!
# ['All', 'I', 'can', 'say', 'is', 'YUM!<br', '/>Sell', 'these', 'in', 'Mexico', 'and', 'you', 'will', 'have', 'a', 'faithful', 'buyer,', 'more', 'often', 'than', "I'm", 'able', 'to', 'buy', 'them', 'right', 'now.']
# Writing file done!
#
#
# 00026_aws_food_reviews.txt
# ['Product', 'received', 'is', 'as', 'advertised.<br', '/><br', '/><a', 'href="http://www.amazon.com/gp/product/B001GVISJM">Twizzlers,', 'Strawberry,', '16-Ounce', 'Bags', '(Pack', 'of', '6)</a>']
# Writing file done!
#
#
# 00027_aws_food_reviews.txt
# ['The', 'candy', 'is', 'just', 'red', ',', 'No', 'flavor', '.']
# Writing file done!
# ['Just', 'plan', 'and', 'chewy', '.']
# Writing file done!
# ['I', 'would', 'never', 'buy', 'them', 'again']
# Writing file done!
#
#
# 00028_aws_food_reviews.txt
# ['I', 'was', 'so', 'glad', 'Amazon', 'carried', 'these', 'batteries.']
# Writing file done!
# ['I', 'have', 'a', 'hard', 'time', 'finding', 'them', 'elsewhere', 'because', 'they', 'are', 'such', 'a', 'unique', 'size.']
# Writing file done!
# ['I', 'need', 'them', 'for', 'my', 'garage', 'door', 'opener.<br', '/>Great', 'deal', 'for', 'the', 'price.']
# Writing file done!
#
#
# 00029_aws_food_reviews.txt
# ['I', 'got', 'this', 'for', 'my', 'Mum', 'who', 'is', 'not', 'diabetic', 'but', 'needs', 'to', 'watch', 'her', 'sugar', 'intake,', 'and', 'my', 'father', 'who', 'simply', 'chooses', 'to', 'limit', 'unnecessary', 'sugar', 'intake', '-', "she's", 'the', 'one', 'with', 'the', 'sweet', 'tooth', '-', 'they', 'both', 'LOVED', 'these', 'toffees,', 'you', 'would', 'never', 'guess', 'that', "they're", 'sugar-free', 'and', "it's", 'so', 'great', 'that', 'you', 'can', 'eat', 'them', 'pretty', 'much', 'guilt', 'free!']
# Writing file done!
# ['i', 'was', 'so', 'impressed', 'that', "i've", 'ordered', 'some', 'for', 'myself', '(w', 'dark', 'chocolate)', 'to', 'take', 'to', 'the', 'office', 'so', "i'll", 'eat', 'them', 'instead', 'of', 'snacking', 'on', 'sugary', 'sweets.<br', '/>These', 'are', 'just', 'EXCELLENT!']
# Writing file done!
#
#
# 00030_aws_food_reviews.txt
# ['I', "don't", 'know', 'if', "it's", 'the', 'cactus', 'or', 'the', 'tequila', 'or', 'just', 'the', 'unique', 'combination', 'of', 'ingredients,', 'but', 'the', 'flavour', 'of', 'this', 'hot', 'sauce', 'makes', 'it', 'one', 'of', 'a', 'kind!']
# Writing file done!
# ['We', 'picked', 'up', 'a', 'bottle', 'once', 'on', 'a', 'trip', 'we', 'were', 'on', 'and', 'brought', 'it', 'back', 'home', 'with', 'us', 'and', 'were', 'totally', 'blown', 'away!']
# Writing file done!
# ['When', 'we', 'realized', 'that', 'we', 'simply', "couldn't", 'find', 'it', 'anywhere', 'in', 'our', 'city', 'we', 'were', 'bummed.<br', '/><br', '/>Now,', 'because', 'of', 'the', 'magic', 'of', 'the', 'internet,', 'we', 'have', 'a', 'case', 'of', 'the', 'sauce', 'and', 'are', 'ecstatic', 'because', 'of', 'it.<br', '/><br', '/>If', 'you', 'love', 'hot', 'sauce..I', 'mean', 'really', 'love', 'hot', 'sauce,', 'but', "don't", 'want', 'a', 'sauce', 'that', 'tastelessly', 'burns', 'your', 'throat,', 'grab', 'a', 'bottle', 'of', 'Tequila', 'Picante', 'Gourmet', 'de', 'Inclan.']
# Writing file done!
# ['Just', 'realize', 'that', 'once', 'you', 'taste', 'it,', 'you', 'will', 'never', 'want', 'to', 'use', 'any', 'other', 'sauce.<br', '/><br', '/>Thank', 'you', 'for', 'the', 'personal,', 'incredible', 'service!']
# Writing file done!
#
#
# 00031_aws_food_reviews.txt
# ['I', 'have', 'never', 'been', 'a', 'huge', 'coffee', 'fan.']
# Writing file done!
# ['However,', 'my', 'mother', 'purchased', 'this', 'little', 'machine', 'and', 'talked', 'me', 'into', 'trying', 'the', 'Latte', 'Macciato.']
# Writing file done!
# ['No', 'Coffee', 'Shop', 'has', 'a', 'better', 'one', 'and', 'I', 'like', 'most', 'of', 'the', 'other', 'products,', 'too', '(as', 'a', 'usually', 'non-coffee', 'drinker!']
# Writing file done!
# [').<br', '/>The', 'little', 'Dolche', 'Guesto', 'Machine', 'is', 'super', 'easy', 'to', 'use', 'and', 'prepares', 'a', 'really', 'good', 'Coffee/Latte/Cappuccino/etc', 'in', 'less', 'than', 'a', 'minute', '(if', 'water', 'is', 'heated', 'up).']
# Writing file done!
# ['I', 'would', 'recommend', 'the', 'Dolce', 'Gusto', 'to', 'anyone.']
# Writing file done!
# ['Too', 'good', 'for', 'the', 'price', 'and', "I'am", 'getting', 'one', 'myself!']
# Writing file done!
# [':)']
# Writing file done!
#
#
# 00032_aws_food_reviews.txt
# ['This', 'offer', 'is', 'a', 'great', 'price', 'and', 'a', 'great', 'taste,', 'thanks', 'Amazon', 'for', 'selling', 'this', 'product.<br', '/><br', '/>Staral']
# Writing file done!
#
#
# 00033_aws_food_reviews.txt
# ["McCann's", 'Instant', 'Oatmeal', 'is', 'great', 'if', 'you', 'must', 'have', 'your', 'oatmeal', 'but', 'can', 'only', 'scrape', 'together', 'two', 'or', 'three', 'minutes', 'to', 'prepare', 'it.']
# Writing file done!
# ['There', 'is', 'no', 'escaping', 'the', 'fact,', 'however,', 'that', 'even', 'the', 'best', 'instant', 'oatmeal', 'is', 'nowhere', 'near', 'as', 'good', 'as', 'even', 'a', 'store', 'brand', 'of', 'oatmeal', 'requiring', 'stovetop', 'preparation.']
# Writing file done!
# ['Still,', 'the', "McCann's", 'is', 'as', 'good', 'as', 'it', 'gets', 'for', 'instant', 'oatmeal.']
# Writing file done!
# ["It's", 'even', 'better', 'than', 'the', 'organic,', 'all-natural', 'brands', 'I', 'have', 'tried.']
# Writing file done!
# ['All', 'the', 'varieties', 'in', 'the', "McCann's", 'variety', 'pack', 'taste', 'good.']
# Writing file done!
# ['It', 'can', 'be', 'prepared', 'in', 'the', 'microwave', 'or', 'by', 'adding', 'boiling', 'water', 'so', 'it', 'is', 'convenient', 'in', 'the', 'extreme', 'when', 'time', 'is', 'an', 'issue.<br', '/><br', "/>McCann's", 'use', 'of', 'actual', 'cane', 'sugar', 'instead', 'of', 'high', 'fructose', 'corn', 'syrup', 'helped', 'me', 'decide', 'to', 'buy', 'this', 'product.']
# Writing file done!
# ['Real', 'sugar', 'tastes', 'better', 'and', 'is', 'not', 'as', 'harmful', 'as', 'the', 'other', 'stuff.']
# Writing file done!
# ['One', 'thing', 'I', 'do', 'not', 'like,', 'though,', 'is', "McCann's", 'use', 'of', 'thickeners.']
# Writing file done!
# ['Oats', 'plus', 'water', 'plus', 'heat', 'should', 'make', 'a', 'creamy,', 'tasty', 'oatmeal', 'without', 'the', 'need', 'for', 'guar', 'gum.']
# Writing file done!
# ['But', 'this', 'is', 'a', 'convenience', 'product.']
# Writing file done!
# ['Maybe', 'the', 'guar', 'gum', 'is', 'why,', 'after', 'sitting', 'in', 'the', 'bowl', 'a', 'while,', 'the', 'instant', "McCann's", 'becomes', 'too', 'thick', 'and', 'gluey.']
# Writing file done!
#
#
# 00034_aws_food_reviews.txt
# ['This', 'is', 'a', 'good', 'instant', 'oatmeal', 'from', 'the', 'best', 'oatmeal', 'brand.']
# Writing file done!
# ['It', 'uses', 'cane', 'sugar', 'instead', 'of', 'high', 'fructouse', 'corn', 'syrup,', 'so', 'not', 'only', 'does', 'it', 'have', 'a', 'better', 'sweetness,', 'but', 'some', 'doctors', 'now', 'say', 'that', 'this', 'form', 'of', 'sugar', 'is', 'better', 'for', 'you.']
# Writing file done!
# ['Great', 'on', 'a', 'cold', 'morning', 'when', 'you', "don't", 'have', 'time', 'to', 'make', "McCann's", 'Steel', 'Cut', 'Oats.']
# Writing file done!
# ['The', 'apple', 'cinnamon', 'is', 'the', 'best', 'but', 'the', 'maple', 'and', 'brown', 'sugar', 'or', 'the', 'regular', 'are', 'good', 'too.']
# Writing file done!
# ['Plus', 'they', "don't", 'require', 'doctoring', 'to', 'actually', 'tell', 'the', 'three', 'flavors', 'apart.']
# Writing file done!
#
#
# 00035_aws_food_reviews.txt
# ['Instant', 'oatmeal', 'can', 'become', 'soggy', 'the', 'minute', 'the', 'water', 'hits', 'the', 'bowl.']
# Writing file done!
# ["McCann's", 'Instant', 'Oatmeal', 'holds', 'its', 'texture,', 'has', 'excellent', 'flavor,', 'and', 'is', 'good', 'for', 'you', 'all', 'at', 'the', 'same', 'time.']
# Writing file done!
# ["McCann's", 'regular', 'oat', 'meal', 'is', 'excellent,', 'too,', 'but', 'may', 'take', 'a', 'bit', 'longer', 'to', 'prepare', 'than', 'most', 'have', 'time', 'for', 'in', 'the', 'morning.']
# Writing file done!
# ['This', 'is', 'the', 'best', 'instant', 'brand', "I've", 'ever', 'eaten,', 'and', 'a', 'very', 'close', 'second', 'to', 'the', 'non-instant', 'variety.<br', '/><br', "/>McCann's", 'Instant', 'Irish', 'Oatmeal,', 'Variety', 'Pack', 'of', 'Regular,', 'Apples', '&', 'Cinnamon,', 'and', 'Maple', '&', 'Brown', 'Sugar,', '10-Count', 'Boxes', '(Pack', 'of', '6)']
# Writing file done!
#
#
# 00036_aws_food_reviews.txt
# ["McCann's", 'Instant', 'Irish', 'Oatmeal,', 'Variety', 'Pack', 'of', 'Regular,', 'Apples', '&', 'Cinnamon,', 'and', 'Maple', '&', 'Brown', 'Sugar,', '10-Count', 'Boxes', '(Pack', 'of', '6)<br', '/><br', "/>I'm", 'a', 'fan', 'of', 'the', "McCann's", 'steel-cut', 'oats,', 'so', 'I', 'thought', "I'd", 'give', 'the', 'instant', 'variety', 'a', 'try.']
# Writing file done!
# ['I', 'found', 'it', 'to', 'be', 'a', 'hardy', 'meal,', 'not', 'too', 'sweet,', 'and', 'great', 'for', 'folks', 'like', 'me', '(post-bariatric', 'surgery)', 'who', 'need', 'food', 'that', 'is', 'palatable,', 'easily', 'digestible,', 'with', 'fiber', 'but', "won't", 'make', 'you', 'bloat.']
# Writing file done!
#
#
# 00037_aws_food_reviews.txt
# ['For', 'those', 'of', 'us', 'with', 'celiac', 'disease', 'this', 'product', 'is', 'a', 'lifesaver', 'and', 'what', 'could', 'be', 'better', 'than', 'getting', 'it', 'at', 'almost', 'half', 'the', 'price', 'of', 'the', 'grocery', 'or', 'health', 'food', 'store!']
# Writing file done!
# ['I', 'love', "McCann's", 'instant', 'oatmeal', '-', 'all', 'flavors!!']
# Writing file done!
# ['!<br', '/><br', '/>Thanks,<br', '/>Abby']
# Writing file done!
#
#
# 00038_aws_food_reviews.txt
# ['What', 'else', 'do', 'you', 'need', 'to', 'know?']
# Writing file done!
# ['Oatmeal,', 'instant', '(make', 'it', 'with', 'a', 'half', 'cup', 'of', 'low-fat', 'milk', 'and', 'add', 'raisins;nuke', 'for', '90', 'seconds).']
# Writing file done!
# ['More', 'expensive', 'than', 'Kroger', 'store', 'brand', 'oatmeal', 'and', 'maybe', 'a', 'little', 'tastier', 'or', 'better', 'texture', 'or', 'something.']
# Writing file done!
# ["It's", 'still', 'just', 'oatmeal.']
# Writing file done!
# ['Mmm,', 'convenient!']
# Writing file done!
#
#
# 00039_aws_food_reviews.txt
# ['I', 'WAS', 'VISITING', 'MY', 'FRIEND', 'NATE', 'THE', 'OTHER', 'MORNING', 'FOR', 'COFFEE', ',', 'HE', 'CAME', 'OUT', 'OF', 'HIS', 'STORAGE', 'ROOM', 'WITH', '(', 'A', 'PACKET', 'OF', 'McCANNS', 'INSTANT', 'IRISH', 'OATMEAL', '.)']
# Writing file done!
# ['HE', 'SUGGESTED', 'THAT', 'I', 'TRY', 'IT', 'FOR', 'MY', 'OWN', 'USE', ',IN', 'MY', 'STASH', '.']
# Writing file done!
# ['SOMETIMES', 'NATE', 'DOSE', 'NOT', 'GIVE', 'YOU', 'A', 'CHANCE', 'TO', 'SAY', 'NO', ',', 'SO', 'I', 'ENDED', 'UP', 'TRYING', 'THE', 'APPLE', 'AND', 'CINN', '.']
# Writing file done!
# ['FOUND', 'IT', 'TO', 'BE', 'VERY', 'TASTEFULL', 'WHEN', 'MADE', 'WITH', 'WATER', 'OR', 'POWDERED', 'MILK', '.']
# Writing file done!
# ['IT', 'GOES', 'GOOD', 'WITH', 'O.J.']
# Writing file done!
# ['AND', 'COFFEE', 'AND', 'A', 'SLICE', 'OF', 'TOAST', 'AND', 'YOUR', 'READY', 'TO', 'TAKE', 'ON', 'THE', 'WORLD...OR', 'THE', 'DAY', 'AT', 'LEAST..', 'JERRY', 'REITH...']
# Writing file done!
#
#
# 00040_aws_food_reviews.txt
# ['I', 'ordered', 'this', 'for', 'my', 'wife', 'as', 'it', 'was', 'reccomended', 'by', 'our', 'daughter.']
# Writing file done!
# ['She', 'has', 'this', 'almost', 'every', 'morning', 'and', 'likes', 'all', 'flavors.']
# Writing file done!
# ["She's", 'happy,', "I'm", 'happy!!']
# Writing file done!
# ['!<br', '/><a', 'href="http://www.amazon.com/gp/product/B001EO5QW8">McCANN\'S', 'Instant', 'Irish', 'Oatmeal,', 'Variety', 'Pack', 'of', 'Regular,', 'Apples', '&', 'Cinnamon,', 'and', 'Maple', '&', 'Brown', 'Sugar,', '10-Count', 'Boxes', '(Pack', 'of', '6)</a>']
# Writing file done!
#
#
# 00041_aws_food_reviews.txt
# ['The', 'variety', 'packs', 'taste', 'great!<br', '/><br', '/>I', 'have', 'them', 'every', 'morning.']
# Writing file done!
# ['At', '$0.30', 'cents', 'per', 'meal,', 'I', "don't", 'understand', 'why', 'everyone', 'on', 'earth', "isn't", 'buying', 'this', 'stuff', 'up.<br', '/><br', '/>Maple', 'and', 'brown', 'sugar', 'is', 'terrific,', 'followed', 'by', 'apples', 'and', 'cinnamon,', 'followed', 'by', 'regular.']
# Writing file done!
# ['You', "don't", 'get', 'tired', 'of', 'the', 'same', 'ole', 'thing,', 'and', 'they', 'taste', 'great.<br', '/><br', '/>I', 'just', 'boil', 'water', 'from', 'a', 'small', 'pot,', 'empty', 'the', 'packet', 'or', '2', 'in', 'a', 'bowl,', 'pour', 'in', 'boiling', 'water,', 'and', 'watch', 'it', 'expand', 'to', '2x', 'its', 'size!<br', '/><br', '/>Taste', 'really', 'good', 'and', 'takes', 'minutes', 'to', 'prepare.<br', '/><br', '/>Not', 'sure', 'why', 'everyone', 'on', 'earth', "isn't", 'this.']
# Writing file done!
# ['Convenient,', 'healthy,', 'very', 'quick,', 'excellent', 'quality,', 'and', 'extremely', 'cheap...']
# Writing file done!
#
#
# 00042_aws_food_reviews.txt
# ["McCann's", 'makes', 'oatmeal', 'for', 'every', 'oatmeal', 'connoisseur,', 'whether', 'one', 'likes', 'it', 'from', 'the', 'raw', 'pellet', 'state', 'that', 'cooks', 'for', 'half', 'an', 'hour,', 'to', 'the', 'sloth', 'addled', 'instant,', 'which', 'can', 'be', 'done', 'in', 'the', 'microwave', 'for', 'under', 'three', 'minutes.']
# Writing file done!
# ["It's", 'all', 'good,', "that's", 'for', 'sure,', 'and', 'the', 'beauty', 'of', 'the', 'instant', 'variety', 'is', 'that', 'it', 'is', 'available', 'in', 'different', 'flavors', 'as', 'well', 'as', 'regular.<br', '/>', 'This', 'variety', 'pack', 'allows', 'different', 'tastes', 'to', 'be', 'explored,', 'as', 'well', 'as', 'giving', 'you', 'a', 'chance', 'to', 'experience', 'the', 'difference', 'between', "McCann's", 'and', 'other', 'well-known', 'oatmeals.']
# Writing file done!
# ['What', 'I', 'personally', 'like', 'about', "McCann's", 'is', 'that', 'it', 'cooks', 'up', 'thicker', 'and', 'with', 'more', 'body', 'than', 'the', 'top', 'brand', 'here', 'in', 'America.']
# Writing file done!
# ['The', 'Apples', '&', 'Cinnamon,', 'though,', 'tends', 'to', 'be', 'a', 'little', 'liquidy', 'so', 'you', 'may', 'want', 'to', 'experiment', 'with', 'the', 'amount', 'of', 'water', 'you', 'add.']
# Writing file done!
# ['In', 'my', '1300watt', 'microwave', 'the', 'oatmeal', 'cooks', 'up', 'in', 'about', 'one', 'minute', 'and', 'twenty-seven', 'seconds,', 'so', 'you', 'should', 'also', 'watch', 'that', 'to', 'get', 'a', 'handle', 'on', 'how', 'much', 'time', 'and', 'water', 'to', 'use.<br', '/>', 'The', 'only', 'bad', 'thing', '--', 'if', 'you', 'can', 'consider', 'it', 'a', 'bad', 'thing', '--', 'about', 'this', 'offering', 'is', 'that', 'you', 'have', 'to', 'buy', 'in', 'lot', 'so', "you'll", 'end', 'up', 'with', 'six', 'ten-count', 'boxes.']
# Writing file done!
# ['This', 'is', 'good', 'if', 'you', 'have', 'a', 'whole', 'family', 'of', 'oatmeal-eaters,', 'but', 'if', "you're", 'a', 'single', 'person', 'alone', '--', 'well,', 'love', 'oatmeal.']
# Writing file done!
#
#
# 00043_aws_food_reviews.txt
# ['I', 'have', "McCann's", 'Oatmeal', 'every', 'morning', 'and', 'by', 'ordering', 'it', 'from', 'Amazon', 'I', 'am', 'able', 'to', 'save', 'almost', '$3.00', 'per', 'box.<br', '/>It', 'is', 'a', 'great', 'product.']
# Writing file done!
# ['Tastes', 'great', 'and', 'very', 'healthy']
# Writing file done!
#
#
# 00044_aws_food_reviews.txt
# ["McCann's", 'Oatmeal', 'is', 'a', 'good', 'quality', 'choice.']
# Writing file done!
# ['Our', 'favorite', 'is', 'the', 'Apples', 'and', 'Cinnamon,', 'but', 'we', 'find', 'that', 'none', 'of', 'these', 'are', 'overly', 'sugary.']
# Writing file done!
# ['For', 'a', 'good', 'hot', 'breakfast', 'in', '2', 'minutes,', 'this', 'is', 'excellent.']
# Writing file done!
#
#
# 00045_aws_food_reviews.txt
# ['We', 'really', 'like', 'the', "McCann's", 'steel', 'cut', 'oats', 'but', 'find', 'we', "don't", 'cook', 'it', 'up', 'too', 'often.<br', '/>This', 'tastes', 'much', 'better', 'to', 'me', 'than', 'the', 'grocery', 'store', 'brands', 'and', 'is', 'just', 'as', 'convenient.<br', '/>Anything', 'that', 'keeps', 'me', 'eating', 'oatmeal', 'regularly', 'is', 'a', 'good', 'thing.']
# Writing file done!
#
#
# 00046_aws_food_reviews.txt
# ['This', 'seems', 'a', 'little', 'more', 'wholesome', 'than', 'some', 'of', 'the', 'supermarket', 'brands,', 'but', 'it', 'is', 'somewhat', 'mushy', 'and', "doesn't", 'have', 'quite', 'as', 'much', 'flavor', 'either.']
# Writing file done!
# ['It', "didn't", 'pass', 'muster', 'with', 'my', 'kids,', 'so', 'I', 'probably', "won't", 'buy', 'it', 'again.']
# Writing file done!
#
#
# 00047_aws_food_reviews.txt
# ['Good', 'oatmeal.']
# Writing file done!
# ['I', 'like', 'the', 'apple', 'cinnamon', 'the', 'best.']
# Writing file done!
# ['Though', 'I', "wouldn't", 'follow', 'the', 'directions', 'on', 'the', 'package', 'since', 'it', 'always', 'comes', 'out', 'too', 'soupy', 'for', 'my', 'taste.']
# Writing file done!
# ['That', 'could', 'just', 'be', 'me', 'since', 'I', 'like', 'my', 'oatmeal', 'really', 'thick', 'to', 'add', 'some', 'milk', 'on', 'top', 'of.']
# Writing file done!
#
#
# 00048_aws_food_reviews.txt
# ['The', 'flavors', 'are', 'good.']
# Writing file done!
# ['However,', 'I', 'do', 'not', 'see', 'any', 'differce', 'between', 'this', 'and', 'Oaker', 'Oats', 'brand', '-', 'they', 'are', 'both', 'mushy.']
# Writing file done!
#
#
# 00049_aws_food_reviews.txt
# ['I', 'really', 'like', 'the', 'Maple', 'and', 'Brown', 'Sugar', 'flavor.']
# Writing file done!
# ['The', 'regular', 'is', 'fine', 'with', 'brown', 'sugar', 'added.']
# Writing file done!
# ['The', 'Apples', 'and', 'Cinnamon', 'flavor', 'is', 'OK.']
# Writing file done!
# ['This', 'is', 'a', 'very', 'quick,', 'easy', 'and', 'satisfying', 'breakfast', 'and', "I'll", 'order', 'this', 'brand', 'again,', 'but', 'not', 'the', 'variety.']
# Writing file done!
# ["I'll", 'get', 'all', 'Maple', 'and', 'Brown', 'Sugar.']
# Writing file done!
#
#
# 00050_aws_food_reviews.txt
# ['This', 'is', 'the', 'same', 'stuff', 'you', 'can', 'buy', 'at', 'the', 'big', 'box', 'stores.']
# Writing file done!
# ['There', 'is', 'nothing', 'healthy', 'about', 'it.']
# Writing file done!
# ['It', 'is', 'just', 'carbs', 'and', 'sugars.']
# Writing file done!
# ['Save', 'your', 'money', 'and', 'get', 'something', 'that', 'at', 'least', 'has', 'some', 'taste.']
# Writing file done!
#
#
# 00051_aws_food_reviews.txt
# ['This', 'oatmeal', 'is', 'not', 'good.']
# Writing file done!
# ['Its', 'mushy,', 'soft,', 'I', "don't", 'like', 'it.']
# Writing file done!
# ['Quaker', 'Oats', 'is', 'the', 'way', 'to', 'go.']
# Writing file done!
#
#
# 00052_aws_food_reviews.txt
# ['Got', 'a', 'free', 'package', 'of', 'these', 'with', 'a', 'bottle', 'of', 'bloody', 'mary', 'mix', 'I', 'bought', 'from', 'the', 'seller,', 'and', 'the', 'advertising', 'worked..lol,', 'I', 'tried', 'them,', 'and', 'shared', 'them', 'with', '2', 'buddies,', 'and', 'we', 'all', 'loved', 'them...']
# Writing file done!
# ['So', 'im', 'here', 'to', 'buy', 'more,', 'and', 'noticed', 'there', 'were', 'no', 'reviews', 'yet,...', 'well', 'now', 'there', 'is.']
# Writing file done!
# ['They', 'are', 'Hot,', 'but', 'not', '"burn', 'your', 'mouth', 'forever', 'hot"', 'its', 'a', 'nice', 'temp...']
# Writing file done!
# ['Perfect', 'for', 'us..']
# Writing file done!
#
#
# 00053_aws_food_reviews.txt
# ['This', "wasn't", 'in', 'stock', 'the', 'last', 'time', 'I', 'looked.']
# Writing file done!
# ['I', 'had', 'to', 'go', 'to', 'the', 'Vermont', 'Country', 'Store', 'in', 'Weston', 'to', 'find', 'it', 'along', 'with', 'a', 'jaw', 'harp,', 'Cranberry', 'Horseradish', 'Sauce,', 'Fartless', 'Black', 'Bean', 'Salsa,', 'Apple', 'Cider', 'Jelly,', "Newton's", 'Cradle', 'Art', 'in', 'Motion', 'and', 'the', 'staple', 'Vermont', 'Maple', 'Syrup.<br', '/><br', '/>Back', 'to', 'the', 'Ass', 'Kickin', 'Peanuts.']
# Writing file done!
# ['They', 'are', 'hot.']
# Writing file done!
# ['They', 'will', 'activate', 'the', 'perspiration', 'glands', 'behind', 'your', 'ears', 'and', 'under', 'your', 'arms.']
# Writing file done!
# ['It', 'requires', 'a', 'beverage', 'as', 'advertised,', 'a', 'glass', 'of', 'very', 'cold', 'milk,', 'and', 'a', 'box', 'of', 'Kleenex', 'since', 'it', 'will', 'make', 'your', 'nose', 'run.']
# Writing file done!
# ['They', 'look', 'like', 'ordinary', 'peanuts', 'which', 'is', 'already', 'giving', 'me', 'ideas', 'for', 'work.']
# Writing file done!
# ['I', 'suspect', 'that', 'some', 'people', 'have', 'been', 'hitting', 'my', 'goodies', 'in', 'my', 'absence,', 'especially', 'my', 'colleague', 'Greg.']
# Writing file done!
# ["I'm", 'going', 'to', 'take', 'this', 'to', 'work', 'at', 'earliest', 'opportunity', 'and', 'empty', 'the', 'contents', 'of', 'this', 'can', 'into', 'an', 'ordinary', 'Planters', 'Peanuts', 'can,', 'and', 'then', 'see', 'whose', 'crying', 'or', 'whose', 'nose', 'is', 'running', 'when', 'I', 'return.<br', '/><br', '/>The', 'can', 'should', 'be', 'shaken', 'to', 'ensure', 'the', 'spices', 'are', 'evenly', 'distributed.']
# Writing file done!
# ['It', 'is', 'important', 'to', 'wash', 'your', 'hands', 'after', 'consumption', 'and', 'not', 'touch', 'the', 'eyes.<br', '/><br', "/>You'll", 'go', 'nuts', 'over', 'these', "Ass-Kickin'", 'Peanuts.<br', '/><br', '/>P.S.']
# Writing file done!
# ["I'm", 'not', 'sharing', 'the', 'peanuts,', 'not', 'deliberately,', 'and', "I'll", 'probably', 'give', 'Greg', 'the', 'jaw', 'harp', 'for', 'Christmas.']
# Writing file done!
# ["He'll", 'be', 'so', 'insulted.']
# Writing file done!
#
#
# 00054_aws_food_reviews.txt
# ["we're", 'used', 'to', 'spicy', 'foods', 'down', 'here', 'in', 'south', 'texas', 'and', 'these', 'are', 'not', 'at', 'all', 'spicy.']
# Writing file done!
# ['doubt', 'very', 'much', 'habanero', 'is', 'used', 'at', 'all.']
# Writing file done!
# ['could', 'take', 'it', 'up', 'a', 'notch', 'or', 'two.']
# Writing file done!
#
#
# 00055_aws_food_reviews.txt
# ['I', 'roast', 'at', 'home', 'with', 'a', 'stove-top', 'popcorn', 'popper', '(but', 'I', 'do', 'it', 'outside,', 'of', 'course).']
# Writing file done!
# ['These', 'beans', '(Coffee', 'Bean', 'Direct', 'Green', 'Mexican', 'Altura)', 'seem', 'to', 'be', 'well-suited', 'for', 'this', 'method.']
# Writing file done!
# ['The', 'first', 'and', 'second', 'cracks', 'are', 'distinct,', 'and', "I've", 'roasted', 'the', 'beans', 'from', 'medium', 'to', 'slightly', 'dark', 'with', 'great', 'results', 'every', 'time.']
# Writing file done!
# ['The', 'aroma', 'is', 'strong', 'and', 'persistent.']
# Writing file done!
# ['The', 'taste', 'is', 'smooth,', 'velvety,', 'yet', 'lively.']
# Writing file done!
#
#
# 00056_aws_food_reviews.txt
# ['We', 'roast', 'these', 'in', 'a', 'large', 'cast', 'iron', 'pan', 'on', 'the', 'grill', '(about', '1/3', 'of', 'the', 'bag', 'at', 'a', 'time).']
# Writing file done!
# ['The', 'smell', 'is', 'wonderful', 'and', 'the', 'roasted', 'beans', 'taste', 'delicious', 'too.']
# Writing file done!
# ['More', 'importantly,', 'the', 'coffee', 'is', 'smooth;', 'no', 'bitter', 'aftertaste.']
# Writing file done!
# ['On', 'numerous', 'occasions,', "we've", 'had', 'to', 'send', 'the', 'roasted', 'beans', 'home', 'with', 'friends', 'because', 'they', 'like', 'it', 'so', 'much.']
# Writing file done!
#
#
# 00057_aws_food_reviews.txt
# ['Deal', 'was', 'awesome!']
# Writing file done!
# ['Arrived', 'before', 'Halloween', 'as', 'indicated', 'and', 'was', 'enough', 'to', 'satisfy', 'trick', 'or', 'treaters.']
# Writing file done!
# ['I', 'love', 'the', 'quality', 'of', 'this', 'product', 'and', 'it', 'was', 'much', 'less', 'expensive', 'than', 'the', 'local', "store's", 'candy.']
# Writing file done!
#
#
# 00058_aws_food_reviews.txt
# ['It', 'is', 'chocolate,', 'what', 'can', 'I', 'say.']
# Writing file done!
# ['Great', 'variety', 'of', 'everything', 'our', 'family', 'loves.']
# Writing file done!
# ['With', 'a', 'family', 'of', 'six', 'it', 'goes', 'fast', 'here.']
# Writing file done!
# ['Perfect', 'variety.']
# Writing file done!
# ['Kit', 'Kat,', 'Reeses,', 'take', 'five', 'and', 'more.']
# Writing file done!
#
#
# 00059_aws_food_reviews.txt
# ['Great', 'product,', 'nice', 'combination', 'of', 'chocolates', 'and', 'perfect', 'size!']
# Writing file done!
# ['The', 'bags', 'had', 'plenty,', 'and', 'they', 'were', 'shipped', 'promptly.']
# Writing file done!
# ['The', 'kids', 'in', 'the', 'neighborhood', 'liked', 'our', 'candies!']
# Writing file done!
#
#
# 00060_aws_food_reviews.txt
# ['Halloween', 'is', 'over', 'but,', 'I', 'sent', 'a', 'bag', 'to', 'my', 'daughters', 'class', 'for', 'her', 'share.']
# Writing file done!
# ['The', 'chocolate', 'was', 'fresh', 'and', 'enjoyed', 'by', 'many.']
# Writing file done!
#
#
# 00061_aws_food_reviews.txt
# ['Watch', 'your', 'prices', 'with', 'this.']
# Writing file done!
# ['While', 'the', 'assortment', 'was', 'good,', 'and', 'I', 'did', 'get', 'this', 'on', 'a', 'gold', 'box', 'purchase,', 'the', 'price', 'for', 'this', 'was<br', '/>$3-4', 'less', 'at', 'Target.']
# Writing file done!
#
#
# 00062_aws_food_reviews.txt
# ['This', 'bag', 'of', 'candy', 'online', 'is', 'pretty', 'expensive,', 'it', 'should', 'be', 'cheaper', 'in', 'order', 'to', 'compete', 'with', 'grocery', 'stores,', 'other', 'than', 'that,', 'its', 'a', 'good', 'combination', 'of', 'my', 'favorite', 'candy']
# Writing file done!
#
#
# 00063_aws_food_reviews.txt
# ['Arrived', 'in', '6', 'days', 'and', 'were', 'so', 'stale', 'i', 'could', 'not', 'eat', 'any', 'of', 'the', '6', 'bags!']
# Writing file done!
# ['!']
# Writing file done!
#
#
# 00064_aws_food_reviews.txt
# ['I', 'have', 'used', 'the', 'endurolyte', 'product', 'for', 'several', 'years', 'in', 'both', 'pill', 'and', 'powder', 'form.']
# Writing file done!
# ['Long', 'desert', 'rides', 'on', 'the', 'dirt', 'bike', 'always', 'found', 'my', 'camelbak', 'water', 'heavily', 'laced', 'with', 'the', 'endurolyte', 'powder,', 'not', 'overly', 'tasty,', 'but', 'quite', 'effective,', 'as', 'I', 'never', 'got', 'a', 'cramp', 'on', 'these', 'several', 'hundred', 'mile', 'rides.']
# Writing file done!
# ['Same', 'for', 'desert', 'racing', 'in', 'the', 'buggy,', 'the', 'camelbaks', 'were', 'always', 'laced', 'with', 'the', 'powder.']
# Writing file done!
# ['Now', 'we', 'have', 'the', 'Fizz...what', 'a', 'great', 'product!']
# Writing file done!
# ['Firstly,', 'its', "Hammer's", 'endurolyte', 'product', 'so', "it's", 'great,', 'endurance', "athlete's", 'the', 'world', 'over', 'use', 'their', 'products.']
# Writing file done!
# ['Second', 'its', 'convenient,', 'handly', 'tablets', 'that', 'dissovle', 'in', 'a', 'fizz.']
# Writing file done!
# ['Third', 'it', 'tastes', 'great!']
# Writing file done!
# ['Imagine', 'getting', 'a', 'nice', 'cool', 'drink', 'when', 'your', 'body', 'is', 'starving', 'for', 'hydration', 'and', 'electrolytes', 'and', 'rather', 'than', 'getting', 'a', '"salty"', 'taste,', 'you', 'get', 'a', 'refreshing', 'lemon-lime', 'or', 'mango!']
# Writing file done!
# ['The', 'camelbaks', 'always', 'get', 'the', 'Fizz', 'now.']
# Writing file done!
# ['I', 'also', 'drop', 'a', 'tablet', 'in', 'my', 'bottled', 'water', 'whenever', 'I', 'exercise', 'and', 'have', 'a', 'nice', 'flavored', 'water', 'chock', 'full', 'of', 'electrolytes.']
# Writing file done!
# ['I', 'cannot', 'recommend', 'this', 'product', 'or', 'any', 'hammer', 'product', 'highly', 'enough.']
# Writing file done!
#
#
# 00065_aws_food_reviews.txt
# ['This', 'product', 'serves', 'me', 'well', 'as', 'a', 'source', 'of', 'electrolytes', 'during', 'and', 'after', 'a', 'long', 'run', 'or', 'bike', 'ride.<br', '/>I', 'have', 'tried', 'all', 'of', 'the', 'flavors', 'but', 'really', 'do', 'like', 'the', 'grapefruit', 'flavor...', 'no', 'after-taste', 'and', 'I', 'actually', 'like', 'the', 'slight', 'carbonation.<br', '/>I', 'use', 'other', 'Hammer', 'products', 'and', 'really', 'like', 'their', 'whole', 'product', 'line.']
# Writing file done!
#
#
# 00066_aws_food_reviews.txt
# ['This', 'stuff', 'really', 'works', 'for', 'preventing', 'cramping', 'during', 'the', 'middle', 'to', 'latter', 'stages', 'of', 'your', 'rides.']
# Writing file done!
# ['Pop', '1', 'into', 'each', 'water', 'bottle', 'and', "you're", 'set.']
# Writing file done!
# ['Flavor', 'is', 'fine', 'and', 'goes', 'down', 'easy.']
# Writing file done!
#
#
# 00067_aws_food_reviews.txt
# ['For', 'those', 'of', 'us', 'on', 'a', 'low', 'carb', 'diet', 'these', 'little', 'tablets', 'are', 'just', 'the', 'thing.<br', '/><br', '/>Two', 'years', 'ago', 'I', 'started', 'cycling', 'again', 'after', 'many', 'years', 'but', 'was', 'having', 'heart', 'arrhythmia', 'after', 'longer', 'rides', 'in', 'high', 'heat.']
# Writing file done!
# ['I', 'was', 'drinking', 'plain', 'water', 'but', 'did', 'a', 'little', 'research', 'and', 'thought', 'electrolytes', 'might', 'be', 'the', 'issue.']
# Writing file done!
# ['Gatorade', "wasn't", 'an', 'option', 'because', 'it', 'is', 'so', 'loaded', 'with', 'carbohydrates', 'so', 'I', 'looked', 'around', 'for', 'a', 'low-carb', 'alternative.']
# Writing file done!
# ['The', '"zero', 'carb"', 'sports', 'drinks', "didn't", 'help', 'so', 'what', 'to', 'do?']
# Writing file done!
# ['One', 'day', 'I', 'ran', 'across', 'these', 'at', 'my', 'bike', 'shop', 'so', 'tried', 'a', 'tube', 'of', 'them.....voila!...problem', 'solved!']
# Writing file done!
# ['!<br', '/><br', "/>I've", 'shared', 'them', 'with', 'two', 'friends', 'in', 'particular', 'whose', 'problems', 'with', 'leg', 'cramps', 'were', 'resolved', 'while', 'using', 'these.<br', '/><br', '/>These', 'guys', 'got', 'it', 'right', '--', 'they', 'are', 'superbly', 'formulated', 'and', 'simply', 'work.....']
# Writing file done!
#
#
# 00068_aws_food_reviews.txt
# ['I', 'purchased', 'the', 'Mango', 'flavor,', 'and', 'to', 'me', 'it', "doesn't", 'take', 'like', 'Mango', 'at', 'all.']
# Writing file done!
# ['There', 'is', 'no', 'hint', 'of', 'sweetness,', 'and', 'unfortunately', 'there', 'is', 'a', 'hint', 'or', 'aftertaste', 'almost', 'like', 'licorice.']
# Writing file done!
# ["I've", 'been', 'consuming', 'various', 'sports', 'nutrition', 'products', 'for', 'decades,', 'so', "I'm", 'familiar', 'and', 'have', 'come', 'to', 'like', 'the', 'taste', 'of', 'the', 'most', 'of', 'the', 'products', "I've", 'tried.']
# Writing file done!
# ['The', 'mango', 'flavor', 'is', 'one', 'of', 'the', 'least', 'appealing', "I've", 'tasted.']
# Writing file done!
# ["It's", 'not', 'terrible,', 'but', "it's", 'bad', 'enough', 'that', 'I', 'notice', 'the', 'bad', 'taste', 'every', 'sip', 'I', 'take.']
# Writing file done!
#
#
# 00069_aws_food_reviews.txt
# ['If', "you're", 'impulsive', 'like', 'me,', 'then', '$6', 'is', 'ok.', "Don't", 'get', 'me', 'wrong,', 'the', 'quality', 'of', 'these', 'babies', 'is', 'very', 'good', 'and', 'I', 'have', 'no', 'complaints.']
# Writing file done!
# ['But', 'in', 'retrospect,', 'the', 'price', 'is', 'a', 'little', 'ridiculous', '(esp.']
# Writing file done!
# ['when', 'you', 'add', 'on', 'the', 'shipping).']
# Writing file done!
#
#
# 00070_aws_food_reviews.txt
# ['this', 'was', 'sooooo', 'deliscious', 'but', 'too', 'bad', 'i', 'ate', 'em', 'too', 'fast', 'and', 'gained', '2', 'pds!']
# Writing file done!
# ['my', 'fault']
# Writing file done!
#
#
# 00071_aws_food_reviews.txt
# ['These', 'Albanese', 'gummi', 'bears', 'and', 'rings', 'and', 'so', 'on', 'are', 'very', 'good', 'and', 'tasty', 'and', 'high', 'quality.']
# Writing file done!
# ['The', 'bears', 'even', 'have', 'little', 'faces.']
# Writing file done!
# ['At', 'my', 'local', 'candy', 'store', 'this', 'type', 'of', 'gummi', 'stuff', '(bears,', 'rings,', 'snakes,', 'balls,', 'worms,', 'whatever)', 'are', 'about', '$10/lb.']
# Writing file done!
# ['These', 'twin', 'packs', 'of', '4.5', 'or', '5', 'pound', 'bags', 'is', 'a', 'screaming', 'deal', 'as', 'far', 'as', "I'm", 'concerned.']
# Writing file done!
# ["I'm", 'probably', '50', 'pounds', 'deep', 'in', 'these', "friggin'", 'things.']
# Writing file done!
# ['Consumed!']
# Writing file done!
#
#
# 00072_aws_food_reviews.txt
# ['Grape', 'gummy', 'bears', 'are', 'hard', 'to', 'find', 'in', 'my', 'area.']
# Writing file done!
# ['In', 'fact', 'pretty', 'much', 'anyone', 'I', 'talk', 'to', 'about', 'grape', 'gummy', 'bears', 'they', 'think', "I'm", 'lying.']
# Writing file done!
# ['So', 'I', 'bought', '10lbs...', ':', ')', 'These', 'bears', 'are', 'a', 'little', 'bit', 'bigger', 'then', 'the', 'other', 'brands', 'and', 'have', 'kind', 'of', 'sour', 'kick,', 'but', 'nothing', 'to', 'strong.']
# Writing file done!
# ['I', 'love', 'grape', 'flavored', 'candy/soda', 'and', 'these', 'are', 'pretty', 'good.']
# Writing file done!
# ['There', 'is', 'another', 'company', 'that', 'makes', 'grape', 'gummy', 'bears', 'that', 'are', 'a', 'little', 'bit', 'better', 'in', 'my', 'opinion,', 'but', 'these', 'are', 'well', 'worth', 'it', 'for', 'the', 'price.']
# Writing file done!
# ['I', 'like', 'to', 'use', 'the', 'gummy', 'bears', 'in', 'home', 'made', 'Popsicles', 'with', 'flavored', 'sports', 'drink.']
# Writing file done!
# ['The', 'salt', 'in', 'the', 'sports', 'drink', 'makes', 'for', 'softer', 'popsicles,', 'and', 'the', 'gummy', 'bears', 'are', 'awesome', 'frozen.']
# Writing file done!
# ['They', 'are', 'delicious!']
# Writing file done!
#
#
# 00073_aws_food_reviews.txt
# ['I', 'ordered', 'two', 'of', 'these', 'and', 'two', 'of', 'raspberry', 'latice', 'tarts', 'directly', 'from', 'FantasiCakes', 'website', 'for', 'a', 'dinner', 'party', 'I', 'was', 'hosting.']
# Writing file done!
# ['It', 'arrived', 'fresh', 'and', 'intact.']
# Writing file done!
# ['Very', 'good', 'size.']
# Writing file done!
# ['I', 'froze', 'half', 'for', 'later', 'use.']
# Writing file done!
# ['I', 'am', 'a', 'pastry', 'lover', 'and', 'these', 'were', 'the', 'best', "I've", 'ever', 'tasted.']
# Writing file done!
# ['The', 'pastry', 'was', 'soft,', 'the', 'jam', 'was', 'really', 'good', 'and', 'the', 'taste', 'was', 'great.']
# Writing file done!
# ['They', 'were', 'gone', 'in', 'no', 'time.']
# Writing file done!
# ['My', 'guests', 'were', 'really', 'impressed.']
# Writing file done!
#
#
# 00074_aws_food_reviews.txt
# ['Buyer', 'Beware', 'Please!']
# Writing file done!
# ['This', 'sweetener', 'is', 'not', 'for', 'everybody.']
# Writing file done!
# ['Maltitol', 'is', 'an', 'alcohol', 'sugar', 'and', 'can', 'be', 'undigestible', 'in', 'the', 'body.']
# Writing file done!
# ['You', 'will', 'know', 'a', 'short', 'time', 'after', 'consuming', 'it', 'if', 'you', 'are', 'one', 'of', 'the', 'unsuspecting', 'many', 'who', 'cannot', 'digest', 'it', 'by', 'the', 'extreme', 'intestinal', 'bloating', 'and', 'cramping', 'and', 'massive', 'amounts', 'of', 'gas', 'a', 'person', 'can', 'experience.']
# Writing file done!
# ['Nausea,', 'diarrhea', '&', 'headaches', 'can', 'also', 'be', 'experienced.']
# Writing file done!
# ['I', 'learned', 'my', 'lesson', 'the', 'hard', 'way', 'years', 'ago', 'when', 'I', 'fell', 'in', 'love', 'with', 'the', 'sugar-free', 'chocolates', 'suzanne', 'sommers', 'used', 'to', 'sell.']
# Writing file done!
# ['I', 'thought', "I'd", 'found', 'sugar-free', 'chocolate', 'nirvana', 'at', 'first', 'taste', 'but', 'the', 'bliss', 'was', 'short', 'lived', 'when', 'the', 'terrible', 'side', 'effects', 'of', 'maltitol', 'kicked', 'in.']
# Writing file done!
# ['The', 'discomfort', 'was', 'unlike', 'anything', 'I', 'had', 'ever', 'felt', 'before.']
# Writing file done!
# ['I', 'blew', 'up', 'like', 'a', 'balloon', 'and', 'had', 'very', 'painful', 'abdominal', 'cramping.']
# Writing file done!
# ...
# Writing file done!
# ['I', 'highly', 'recommend', 'it', 'to', 'any', 'coffee', 'lover', 'when', 'you', 'have', 'access', 'to', 'very', 'hot', 'water', 'but', "don't", 'have', 'access', 'to', 'a', 'coffee', 'maker.']
# Writing file done!
# ['Individual', 'wrapped', 'and', 'sealed', 'bags', 'allow', 'you', 'to', 'take', 'one', 'tiny', 'tea', 'like', 'bag', 'with', 'you', 'in', 'your', 'pocket', 'or', 'purse', 'to', 'your', 'early', 'morning', 'meetings.']
# Writing file done!
#
#
# 00976_aws_food_reviews.txt
# ['I', 'keep', 'Regular', 'bags', 'and', 'Decaf', 'bags', 'in', 'my', 'home', 'at', 'all', 'times.<br', '/>Never', 'have', 'to', 'drink', 'old', 'coffee.']
# Writing file done!
# ['Best', 'way', 'to', 'make', 'iced', 'coffee.']
# Writing file done!
#
#
# 00977_aws_food_reviews.txt
# ['I', 'live', 'in', 'the', 'dorms', 'without', 'a', 'kitchen', 'so', 'making', 'a', 'cup', 'of', 'coffee', 'was', 'really', 'easy', 'with', 'this.']
# Writing file done!
# ['Especially', 'when', 'I', 'need', 'to', 'stay', 'up', 'late', 'to', 'study', 'or', 'to', 'wake', 'up', 'after', '2', 'hours', 'of', 'sleep.']
# Writing file done!
# ['Its', 'just', 'like', 'making', 'tea', 'and', 'tastes', 'decent', 'enough.']
# Writing file done!
# ['Not', 'starbucks', 'but', 'good', 'enough', 'with', 'some', 'sugar', 'and', 'cream.']
# Writing file done!
#
#
# 00978_aws_food_reviews.txt
# ['My', 'primary', 'point', 'with', 'this', 'review', 'is', 'to', 'note', 'that', 'this', 'packaging', 'is', 'less', 'expensive', 'than', 'the', 'other', 'size', 'offered', 'by', 'Folger.']
# Writing file done!
# ['You', 'get', 'more', 'coffee', 'for', 'less', 'money.<br', '/><br', '/>', 'I', 'recently', 'started', 'drinking', 'coffee', 'again', 'after', 'a', 'lapse', 'of', 'many', 'years.']
# Writing file done!
# ['Since', 'I', "didn't", 'know', 'how', 'many', 'cups', 'a', 'day', 'I', 'would', 'use,', 'I', 'wanted', 'to', 'avoid', 'the', 'fuss', 'of', 'a', 'coffeemaker.']
# Writing file done!
# ['I', "don't", 'particularly', 'like', 'instant', 'coffee.']
# Writing file done!
# ['I', 'was', 'delighted', 'to', 'find', 'these', "Folger's", 'bags.<br', '/><br', '/>', 'They', 'brew', 'a', 'very', 'nice', 'tasting', 'cup', 'of', 'coffee.']
# Writing file done!
# ["I'm", 'not', 'any', 'kind', 'of', 'coffee', 'expert,', 'so', 'I', "don't", 'know', 'what', 'special', 'terms', 'might', 'be', 'used.']
# Writing file done!
# ['All', 'I', 'know', 'is', 'that', 'if', 'I', 'let', 'the', 'bag', 'seep', 'for', 'a', 'bit', 'more', 'than', 'a', 'minute,', 'it', 'sure', 'tastes', 'good.']
# Writing file done!
# ['Thanks', 'to', 'my', 'very', 'much', 'better', 'half,', "I've", 'also', 'learned', 'that', 'each', 'of', 'these', 'bags', 'will', 'produce', 'at', 'least', 'two', 'good', 'cups', 'of', 'coffee.<br', '/><br', '/>', 'Very', 'convenient,', 'very', 'easy,', 'very', 'tasty.']
# Writing file done!
# ['I', 'intend', 'to', 'take', 'some', 'of', 'these', 'with', 'me', 'when', 'I', 'travel', 'as', 'an', 'alternative', 'to', 'the', 'in-room', 'coffee', 'makers', 'or', '(yeck!)']
# Writing file done!
# ['vending', 'machines.<br', '/><br', '/>Jerry']
# Writing file done!
#
#
# 00979_aws_food_reviews.txt
# ['We', "can't", 'have', 'any', 'kind', 'of', 'coffee', 'maker', 'at', 'work,', 'so', "we're", 'forced', 'to', 'buy', 'at', 'the', 'in-house', 'coffee', 'shop', 'or', "Starbuck's", 'across', 'the', 'street.']
# Writing file done!
# ['In', 'this', 'economy,', 'no', 'one', 'wants', 'to', 'pay', 'those', 'high', 'prices,', 'so', 'we', 'started', 'a', 'coffee', 'club.']
# Writing file done!
# ['20', 'of', 'us', 'buy', 'these', 'coffee', 'bags', 'and', 'separate', 'creamer', 'and', 'enjoy', 'fresh,', 'hot,', 'tasty', 'coffee', 'every', 'day', 'without', 'paying', 'the', 'coffee', 'shop', 'prices.']
# Writing file done!
# ['thanks', 'Folgers!!']
# Writing file done!
# ['!']
# Writing file done!
#
#
# 00980_aws_food_reviews.txt
# ['These', 'are', 'great', 'for', 'at', 'work,', 'just', 'pop', 'the', 'instant', 'bag', 'in', 'for', 'a', 'minute', 'then', 'make', 'your', 'coffee.']
# Writing file done!
# ['This', 'is', 'the', 'best', 'tasting', 'coffee.']
# Writing file done!
# ["It's", 'easy', 'to', 'make', 'without', 'a', 'mess.']
# Writing file done!
#
#
# 00981_aws_food_reviews.txt
# ['Fast,', 'easy', 'and', 'definitely', 'delicious.']
# Writing file done!
# ['Makes', 'a', 'great', 'cup', 'of', 'coffee', 'and', 'very', 'easy', 'to', 'make.']
# Writing file done!
# ['Good', 'purchase.']
# Writing file done!
# ['Will', 'continue', 'to', 'order', 'from', 'here.<br', '/>Thanx...']
# Writing file done!
#
#
# 00982_aws_food_reviews.txt
# ['I', 'gave', 'this', 'tea', 'a', 'try', 'to', 'add', 'variety', 'to', 'my', 'tea', 'habit.']
# Writing file done!
# ['And', "I'm", 'glad', 'I', 'did.']
# Writing file done!
# ['It', 'has', 'a', 'somewhat', 'sweet', 'and', 'almost', 'minty', 'taste', 'and', 'a', 'wonderful', 'aroma.']
# Writing file done!
# ['It', 'has', 'a', 'nice', 'reddish', 'color.']
# Writing file done!
# ['This', 'tea', 'probably', 'has', 'more', 'of', 'a', 'taste', 'factor', 'than', 'any', 'of', 'the', 'wonderful', 'japanese', 'green', 'matcha', 'tea', "I've", 'had,', 'and', 'I', 'look', 'forward', 'to', 'experiencing', 'any', 'of', 'the', 'purported', 'health', 'benefits', 'of', 'rooibos', 'that', "I've", 'read', 'about.']
# Writing file done!
#
#
# 00983_aws_food_reviews.txt
# ['I', 'tried', 'this', 'before', 'having', 'normal', 'red', 'tea', 'so', 'I', 'waited', 'to', 'review.']
# Writing file done!
# ['The', 'flavor', 'still', 'rings', 'in', 'my', 'head', 'it', 'is', 'earthier', 'than', 'rooibos', 'tea', 'and', 'less', 'frity.']
# Writing file done!
# ['The', 'color', 'is', 'that', 'of', 'muddy', 'water,', 'and', 'it', 'has', 'the', 'grittiness', 'and', 'viscosity', 'of', 'it', 'as', 'well.']
# Writing file done!
# ['Well', 'worth', 'every', 'penny.']
# Writing file done!
#
#
# 00984_aws_food_reviews.txt
# ['I', 'previously', 'tried', 'other', 'matcha', 'products', 'and', 'was', 'generally', 'satisfied', 'with', 'the', 'quality', 'but', 'not', 'the', 'price.']
# Writing file done!
# ['I', 'decided', 'to', 'give', 'Pure', 'Matcha', 'green', 'and', 'rooibos', 'a', 'try', 'because', 'the', 'price', 'seemed', 'to', 'be', 'very', 'competitive.']
# Writing file done!
# ['The', 'quality', 'of', 'Pure', "Matcha's", 'products', 'surpasses', 'that', 'of', 'all', 'others', 'I', 'have', 'tried-', 'stays', 'fresh,', 'has', 'a', 'consistent', 'texture', 'and', 'tastes', 'great.']
# Writing file done!
# ['Both', 'the', 'quality', 'and', 'price', 'are', 'better', 'than', 'others', 'that', 'I', 'have', 'purchased', 'for', 'the', 'same', 'quantity.']
# Writing file done!
# ['I', 'highly', 'recommend', 'Pure', 'Matcha', 'and', 'will', 'continue', 'to', 'purchase.']
# Writing file done!
#
#
# 00985_aws_food_reviews.txt
# ['This', 'is', 'the', 'very', 'best', 'marinade', 'you', 'can', 'buy', 'as', 'far', 'as', 'I', 'am', 'concerned---of', 'course,', 'everyone', 'to', 'his', 'or', 'her', 'own', 'tastes,', 'but', 'all', 'in', 'all,', 'I', 'think', 'anyone', 'will', 'like', 'it---I', 'give', 'it', 'five', 'stars...']
# Writing file done!
#
#
# 00986_aws_food_reviews.txt
# ['This', 'is', 'a', 'great', 'product', 'for', 'those', 'looking', 'for', 'an', 'MSG', 'and', 'Gluten', 'free', 'product,', 'and', 'is', 'also', 'lower', 'sodium', 'than', 'any', 'other', 'marinade', 'or', 'soy', 'sauce', 'out', 'there!']
# Writing file done!
# ['It', "doesn't", 'compromise', 'of', 'taste', 'either,', 'I', 'use', 'it', 'as', 'a', 'Soy', 'Sauce', 'substitute', 'and', 'have', 'found', 'it', 'to', 'have', 'superior', 'taste', 'and', 'it', 'looks', 'and', 'acts', 'just', 'like', 'any', 'good', 'marinade', 'should.']
# Writing file done!
# ['If', 'you', 'are', 'Celiac', 'or', 'Gluten', 'intolerant,', 'or', 'even', 'just', 'watching', 'you', 'salt', 'intake,', 'this', 'product', 'is', 'a', 'way', 'to', 'have', 'your', 'steak', 'and', 'marinade', 'it', 'too!']
# Writing file done!
#
#
# 00987_aws_food_reviews.txt
# ['My', 'poland', 'spring', 'driver', 'gave', 'us', 'this', 'new', 'tea', 'to', 'try', 'and<br', '/>our', 'family', 'really', 'enjoyed', 'it.']
# Writing file done!
# ['I', 'looked', 'at', 'the', 'ingredients', 'and', 'was', 'quite', 'pleased<br', '/>with', 'the', 'natural', 'ingredients', 'and', 'no', 'calories.']
# Writing file done!
#
#
# 00988_aws_food_reviews.txt
# ['This', 'hot', 'sauce', 'is', 'one', 'of', 'my', 'favorites.']
# Writing file done!
# ['Its', 'a', 'perfect', 'balance', 'of', 'tasty', 'and', 'spicy.']
# Writing file done!
# ['You', 'can', 'smell', 'the', 'flavors', 'immediately', 'when', 'you', 'open', 'the', 'bottle.']
# Writing file done!
# ['A', 'mix', 'of', 'garlic,', 'habanero,', 'and', 'other', 'spices.']
# Writing file done!
# ['I', 'put', 'this', 'on', 'everything', 'and', 'tend', 'to', 'go', 'through', 'one', 'bottle', 'a', 'week.']
# Writing file done!
# ['I', 'highly', 'recommend', 'this', 'to', 'anyone', 'who', 'likes', 'hot', 'sauce.']
# Writing file done!
#
#
# 00989_aws_food_reviews.txt
# ['I', 'was', 'never', 'much', 'of', 'a', 'hot', 'sauce', 'fan', 'until', 'I', 'tasted', 'Black', 'Market', 'Hot', 'Sauce.']
# Writing file done!
# ['I', 'was', 'listning', 'to', 'the', 'radio', 'one', 'morning', 'and', 'the', 'creater/owner', 'was', 'giving', 'an', 'interview,', 'It', 'sounded', 'interesting.']
# Writing file done!
# ['The', 'D.J.']
# Writing file done!
# ["'s", 'were', 'sampling', 'the', 'sauce', 'and', 'raving', 'about', 'it,', 'So', 'I', 'picked', 'up', 'a', 'bottle', 'at', 'the', 'local', 'grocery,', "It's", 'so', 'good', '!']
# Writing file done!
# ['I', 'keep', 'a', 'bottle', 'in', 'the', 'kitchen', 'and', 'an', 'extra', 'bottle', 'on', 'hand', 'for', 'gifts', 'and', 'for', 'taking', 'to', 'potlucks,barbecues', 'and', "party's."]
# Writing file done!
# ['Happy', 'to', 'see', 'I', 'can', 'buy', 'it', 'online', 'at', 'Amazon.']
# Writing file done!
#
#
# 00990_aws_food_reviews.txt
# ['This', 'is', 'my', 'favorite', 'hot', 'sauce!']
# Writing file done!
# ['I', 'liketo', 'use', 'it', 'to', 'give', 'anything', 'some', 'extra', 'flavor.']
# Writing file done!
# ['I', 'have', 'loved', 'going', 'out', 'to', 'some', 'of', 'my', 'favorite', 'resturants', 'in', 'town', 'and', 'seeing', 'that', 'they', 'are', 'offering', 'this', 'great', 'product.I', 'really', 'enjoy', 'putting', 'on', 'my', 'my', 'breakfast', 'burritos!']
# Writing file done!
#
#
# 00991_aws_food_reviews.txt
# ['They', 'have', 'this', 'in', 'a', 'local', 'diner', 'that', 'I', 'eat', 'in', 'regularly.']
# Writing file done!
# ['I', 'use', 'it', 'on', 'all', 'kinds', 'of', 'foods', 'and', 'I', 'love', 'it.']
# Writing file done!
# ["It's", 'hot,', 'but', 'not', 'without', 'flavor.']
# Writing file done!
# ['I', "don't", 'like', 'those', 'sauces', 'that', 'just', 'burn', 'but', 'have', 'no', 'taste.']
# Writing file done!
# ['This', 'has', 'both', 'burn', 'and', 'and', 'awesome', 'flavor.']
# Writing file done!
# ['I', 'was', 'surprised', 'to', 'find', 'it', 'on', 'Amazon', '(just', 'stumbled', 'across', 'it).']
# Writing file done!
# ['I', 'would', 'highly', 'recommend', 'it', 'to', 'anyone', 'who', 'likes', 'a', 'good', 'hot', 'sauce.']
# Writing file done!
#
#
# 00992_aws_food_reviews.txt
# ['I', 'was', 'browsing', 'around', 'on', 'Amazon', 'looking', 'for', 'gifts', 'and', 'was', 'very', 'pleased', 'to', 'see', 'my', 'favorite', 'sauce', 'on', 'here.']
# Writing file done!
# ['I', 'will', 'just', 'order', 'and', 'have', 'shipped', 'to', 'my', 'friends.']
# Writing file done!
# ['Habanero', 'is', 'my', 'favorite,', 'I', 'love', 'the', 'heat', 'and', 'the', 'tangy', 'spiciness.']
# Writing file done!
# ['I', 'also', 'love', 'the', 'pineapple.']
# Writing file done!
# ['You', 'will', 'not', 'go', 'wrong', 'ordering', 'this', 'up.']
# Writing file done!
#
#
# 00993_aws_food_reviews.txt
# ['This', 'is', 'my', 'favorite', 'hot', 'sauce.']
# Writing file done!
# ['I', 'buy', 'it', 'locally', 'and', 'love', 'the', 'flavor', 'that', 'they', 'all', 'have.']
# Writing file done!
# ['Hopefully', 'the', 'other', 'flavors', 'will', 'show', 'up', 'on', 'amazon', 'for', 'people', 'to', 'enjoy!']
# Writing file done!
# ['My', 'favorites', 'are', 'the', 'medium', 'and', 'pineapple', 'flavored', 'ones', 'so', 'far.']
# Writing file done!
# ['Thank', 'you', 'for', 'making', 'a', 'flavorful', 'hot', 'sauce!']
# Writing file done!
#
#
# 00994_aws_food_reviews.txt
# ['So', 'far', 'I', 'have', 'had', 'the', 'habanero', 'and', 'the', 'medium', 'sauces', 'and', 'they', 'were', 'amazing.']
# Writing file done!
# ['My', 'fiance', 'and', 'I', 'use', 'them', 'nearly', 'daily', 'and', 'I', 'just', 'picked', 'up', '3', 'more.']
# Writing file done!
# ['It', 'goes', 'really', 'well', 'on', 'all', 'sorts', 'of', 'dishes', 'to', 'add', 'the', 'extra', 'kick.<br', '/><br', '/>The', 'sauce', 'itself', 'lasts', 'a', 'lot', 'longer', 'than', 'it', 'appears.']
# Writing file done!
# ['It', 'is', 'thick', 'and', 'a', 'bottle', 'will', 'last', 'us', 'a', 'couple', 'of', 'weeks', 'of', 'heavy', 'use.']
# Writing file done!
# ['We', 'love', 'to', 'use', 'it', 'for', 'breakfast', 'on', 'eggs', 'or', 'in', 'burritos', 'and', 'for', 'dinners', 'or', 'soups', 'for', 'added', 'spice.']
# Writing file done!
#
#
# 00995_aws_food_reviews.txt
# ['absolutely', 'love', 'the', 'habenaro', 'sauce...use', 'it', 'on', 'eggs,', 'sandwiches', 'most', 'anything', 'for', 'a', 'good', 'kick!']
# Writing file done!
# ['have', 'watched', 'the', 'progessing', 'popularity', 'of', 'theis', 'homegrown', 'product...have', 'nothing', 'but', 'the', 'highes', 'accolades', 'for', 'the', 'chef', 'and', 'the', 'product..get', 'out', 'there', 'and', 'try', 'it!']
# Writing file done!
#
#
# 00996_aws_food_reviews.txt
# ['BLACK', 'MARKET', 'HOT', 'SAUCE', 'IS', 'WONDERFUL....', 'My', 'husband', 'Loves', 'this', 'Habenero', 'sauce,', 'its', 'very', 'very', 'flavorful', 'with', 'a', 'nice', 'kick', 'to', 'it.']
# Writing file done!
# ['I', 'in', 'fact', 'love', 'the', 'medium', 'sauce-', 'the', 'taste', 'is', 'so', 'yummy', 'with', 'a', 'bit', 'of', 'zing', 'behind', 'it.']
# Writing file done!
# ['We', 'used', 'it', 'for', 'everything', 'and', 'you', 'can', 'use', 'it', 'with', 'any', 'meal.<br', '/><br', '/>I', 'like', 'the', 'fact', 'that', 'there', 'are', 'so', 'many', 'different', 'levels', 'of', 'spicyness.']
# Writing file done!
# ['We', 'love', 'the', 'medium', '&', 'habenero.']
# Writing file done!
# ['Kind', 'of', 'like', 'a', '"HIS', '&', 'HERS', 'package".']
# Writing file done!
# ['Thank', 'you', 'for', 'your', 'hard', 'work', 'guys!']
# Writing file done!
# ['Keep', 'up', 'the', 'hard', 'work.']
# Writing file done!
#
#
# 00997_aws_food_reviews.txt
# ['Man', 'what', 'can', 'i', 'say,', 'this', 'salsa', 'is', 'the', 'bomb!!']
# Writing file done!
# ['i', 'have', 'all', 'the', 'different', 'kinds.']
# Writing file done!
# ['i', 'have', 'it', 'with', 'almost', 'every', 'meal.']
# Writing file done!
# ['the', 'owner', 'is', 'a', 'cool', 'dude,', "He's", 'dropped', 'off', 'free', 'bottles', 'to', 'me', 'in', 'my', 'mailbox.']
# Writing file done!
# ['i', 'stole', 'the', 'first', 'bottle', 'out', 'of', 'a', 'friends', 'fridge', 'after', 'i', 'tasted', 'and', 'been', 'hooked', 'since.']
# Writing file done!
# ['dont', 'sleep', 'on', 'this', 'hot', 'sauce!']
# Writing file done!
# ['!']
# Writing file done!
#
#
# 00998_aws_food_reviews.txt
# ['this', 'sauce', 'is', 'so', 'good', 'with', 'just', 'about', 'anything,', 'i', 'like', 'adding', 'it', 'to', 'asian', 'food', 'or', 'anything', 'with', 'egg', 'or', 'noodles,', 'it', 'has', 'a', 'good', 'burn', 'with', 'a', 'strong', 'flavor.']
# Writing file done!
# ['im', 'hoping', 'to', 'see', 'some', 'of', 'the', 'other', 'flavors', 'like', 'the', 'pineapple', 'experiment', 'on', 'here', 'soon.']
# Writing file done!
# ['buy', 'it', 'you', 'wont', 'regret', 'it']
# Writing file done!
#
#
# 00999_aws_food_reviews.txt
# ['Not', 'hot', 'at', 'all.']
# Writing file done!
# ['Like', 'the', 'other', 'low', 'star', 'reviewer,', 'I', 'got', 'suckered', 'by', 'seeing', "'habenero'", 'in', 'the', 'name', 'and', 'the', '12', 'oz', 'size.']
# Writing file done!
# ['Some', 'people', 'might', 'like', 'the', 'flavor,', 'citrus-y', 'and', 'it', 'has', 'some', 'fish', 'sauce', 'in', 'the', 'mix', '(according', 'to', 'the', 'ingredient', 'label),', 'but', 'if', "you're", 'looking', 'for', 'hot', 'this', "ain't", 'it']
# Writing file done!

# %%
# from string import punctuation

# with open('Temp/medical.txt', 'r') as f:
    
#     sentences = []
#     needed_sentences = []
    
#     non_disclosure = []
#     disclosure = []
    
#     lines = f.readlines()
#     for line in lines:
#         splitted_line = line.split('   ')
#         if len(splitted_line) >= 3:
#             sentence = splitted_line[2]
            
#             tokens = sentence.split()
#             # remove punctuation from each token
#             table = str.maketrans('', '', punctuation)
#             tokens = [w.translate(table) for w in tokens]
#             doc = ' '.join(tokens)

#             doc = nlp(u''+doc)
#             new_doc = ''
            
#             entity = 0            
#             for t in doc:
#                 if t.ent_type_ == '':
#                     if t.text.upper() in PERSONS:
#                         entity = entity+1
#                         new_doc = doc.text.replace(' '+t.text+' ', ' PERSON ')
#                         doc = nlp(u''+new_doc)
#                     else:
#                         pass
#                 elif t.ent_type_ in ALL_ENTITIES:
#                     entity = entity+1
#                     new_doc = doc.text.replace(t.text, t.ent_type_.upper())
#                     doc = nlp(u''+new_doc)
            
#             if entity != 0:
#                 sentence = new_doc.strip() + ' #OFENTFOUND ' + str(entity)
#                 number_of_ents = int(sentence.split('#OFENTFOUND')[1])
#                 if number_of_ents > 1:
#                     tokens = sentence.split('#OFENTFOUND')[0].split()
#                     if 'PERSON' in tokens:
#                         print('diclosure')
#                         disclosure.append(new_doc.strip() + ' #OFENTFOUND ' + str(entity))
#                         continue
#                     else:
#                         print('non-diclosure')
#                         non_disclosure.append(new_doc.strip() + ' #OFENTFOUND ' + str(entity))
#                         continue            
#                 else:
#                     print('non-diclosure')
#                     non_disclosure.append(new_doc.strip() + ' #OFENTFOUND ' + str(entity))
#                     continue                
#             else:
#                 print('non-diclosure')
#                 non_disclosure.append(new_doc.strip() + ' #OFENTFOUND ' + str(entity))
                
#             sentences.append(sentence)
#         else:
#             pass
        
# print('Disclosure Sentences:', len(disclosure))
# print('Non disclosure Sentences:', len(non_disclosure), '\n')
